# %%
import easygraph as eg
import random
# Out:
#  Please install Pytorch before use graph-related datasets and hypergraph-related datasets.
# Warning raise in module:nn. Please install Pytorch, torch_geometric, torch_scatter before you use functions related to AllDeepSet and AllSetTransformer.
# Warning raise in module:model.Please install Pytorch before you use hypergraph neural networks related to Hypergraph

# %%
# Read 'e-coli.json' dataset
hg = eg.hif_to_hypergraph(filename="data/e-coli.json")
print(hg)
# Out:
# Hypergraph(num_vertex=72, num_hyperedge=93)

# %%
# Output the information of the first five nodes and edges.
print(hg.custom_hif_nodes[:5])
print(hg.custom_hif_edges[:5])
# Out:
# [{'attrs': {'name': 'L-Malate'}, 'node': 'mal__L_c'}, {'attrs': {'name': 'Acetaldehyde'}, 'node': 'acald_e'}, {'attrs': {'name': 'Acetyl phosphate'}, 'node': 'actp_c'}, {'attrs': {'name': 'L-Glutamine'}, 'node': 'gln__L_c'}, {'attrs': {'name': '3-Phospho-D-glycerate'}, 'node': '3pg_c'}]
# [{'attrs': {'name': 'L glutamate transport via proton symport  reversible'}, 'edge': 'GLUt2r'}, {'attrs': {'name': 'Isocitrate dehydrogenase (NADP)'}, 'edge': 'ICDHyr_reverse'}, {'attrs': {'name': 'Glyceraldehyde-3-phosphate dehydrogenase'}, 'edge': 'GAPD'}, {'attrs': {'name': 'Malate synthase'}, 'edge': 'MALS'}, {'attrs': {'name': 'Malate dehydrogenase'}, 'edge': 'MDH_reverse'}]

# %%
# visualization
hg.draw(v_label=hg.v, v_color='#e6928f', e_color='#4e9595')
# Out:
# len(e_list): [(11, 62, 70, 71), (36, 39, 45, 46, 56), (16, 23, 41, 51, 58, 70), (0, 26, 49, 55, 57, 70), (0, 18, 23, 58, 70), (9, 46, 50, 56, 70), (6, 16, 29, 54), (23, 43, 58, 59, 70), (30,), (9, 20, 57, 70), (19, 26, 41, 65, 67, 68), (31, 61, 70, 71), (12, 15, 42, 65), (25, 50), (24,), (18, 33, 36, 41, 57, 70), (71,), (21, 23, 31, 58, 70), (13, 20, 36, 46, 56), (14, 16, 38), (23, 26, 36, 43, 49, 58), (10,), (37,), (21, 23, 26, 49, 58, 70), (48,), (2, 44, 67, 68), (40,), (14, 25, 41, 57), (5, 28), (62,), (43, 53, 70, 71), (19, 23, 26, 36, 39, 58), (15, 23, 42, 58, 70, 71), (1,), (16, 38), (35, 57, 64), (53,), (10, 44, 70, 71), (28,), (33, 43, 67, 68, 70), (26, 43, 49, 66), (5, 15, 42, 57, 70, 71), (3, 11, 41, 67, 68, 69, 70), (0, 36, 43, 46, 56), (16, 25, 54, 63), (41, 57, 67, 68, 70, 71), (8, 33, 41, 43, 57, 68, 70), (60,), (2, 26, 41, 49), (34, 41, 70, 71), (41, 57, 67, 68, 70), (17,), (35, 45, 57), (47,), (3, 24, 41, 57, 67, 68, 70), (11, 39, 46, 56, 57, 69, 70), (52,), (0, 23, 36, 43, 58), (37, 69), (34,), (4, 51, 67, 68), (47, 57), (3, 11, 57, 69), (30, 65, 70, 71), (1, 21), (18, 33, 36, 67, 68), (7, 66, 70, 71), (8, 67, 68), (0, 12, 57), (45, 55, 65), (12, 60, 70, 71), (14, 25, 67, 68, 70), (39, 40, 70, 71), (3, 11, 39, 46, 56, 70), (4, 22), (27, 59, 70, 71), (22, 33, 57), (16, 25, 29, 63), (13, 29), (0, 32, 70, 71), (7,), (32,), (7, 66), (25, 33, 43, 52), (17, 36), (6, 13), (33, 43, 48, 50), (61,), (23, 46, 56, 58, 70, 71), (3, 4, 6, 11, 16, 18, 23, 25, 26, 33, 39, 41, 43, 46, 49, 50, 56, 57, 58, 63, 67, 68, 70), (27,), (23, 46, 56, 58), (18, 26, 49, 57, 64, 70)]

# %%
eg.hypergraph_to_hif(hg, filename="eg_test.json")
# Out:
# {'nodes': [{'attrs': {'name': 'L-Malate'}, 'node': 'mal__L_c'},
#   {'attrs': {'name': 'Acetaldehyde'}, 'node': 'acald_e'},
#   {'attrs': {'name': 'Acetyl phosphate'}, 'node': 'actp_c'},
#   {'attrs': {'name': 'L-Glutamine'}, 'node': 'gln__L_c'},
#   {'attrs': {'name': '3-Phospho-D-glycerate'}, 'node': '3pg_c'},
#   {'attrs': {'name': 'O2 O2'}, 'node': 'o2_c'},
#   {'attrs': {'name': 'Alpha-D-Ribose 5-phosphate'}, 'node': 'r5p_c'},
#   {'attrs': {'name': 'Formate'}, 'node': 'for_e'},
#   {'attrs': {'name': 'AMP C10H12N5O7P'}, 'node': 'amp_c'},
#   {'attrs': {'name': '6-phospho-D-glucono-1,5-lactone'}, 'node': '6pgl_c'},
#   {'attrs': {'name': 'Acetate'}, 'node': 'ac_e'},
#   {'attrs': {'name': 'L-Glutamate'}, 'node': 'glu__L_c'},
#   {'attrs': {'name': 'Fumarate'}, 'node': 'fum_c'},
#   {'attrs': {'name': 'D-Ribulose 5-phosphate'}, 'node': 'ru5p__D_c'},
#   {'attrs': {'name': 'D-Fructose 1,6-bisphosphate'}, 'node': 'fdp_c'},
#   {'attrs': {'name': 'Ubiquinone-8'}, 'node': 'q8_c'},
#   {'attrs': {'name': 'Glyceraldehyde 3-phosphate'}, 'node': 'g3p_c'},
#   {'attrs': {'name': 'CO2 CO2'}, 'node': 'co2_e'},
#   {'attrs': {'name': 'Oxaloacetate'}, 'node': 'oaa_c'},
#   {'attrs': {'name': 'Succinyl-CoA'}, 'node': 'succoa_c'},
#   {'attrs': {'name': '6-Phospho-D-gluconate'}, 'node': '6pgc_c'},
#   {'attrs': {'name': 'Acetaldehyde'}, 'node': 'acald_c'},
#   {'attrs': {'name': 'D-Glycerate 2-phosphate'}, 'node': '2pg_c'},
#   {'attrs': {'name': 'Nicotinamide adenine dinucleotide'}, 'node': 'nad_c'},
#   {'attrs': {'name': 'L-Glutamine'}, 'node': 'gln__L_e'},
#   {'attrs': {'name': 'D-Fructose 6-phosphate'}, 'node': 'f6p_c'},
#   {'attrs': {'name': 'Coenzyme A'}, 'node': 'coa_c'},
#   {'attrs': {'name': 'D-Lactate'}, 'node': 'lac__D_e'},
#   {'attrs': {'name': 'O2 O2'}, 'node': 'o2_e'},
#   {'attrs': {'name': 'D-Xylulose 5-phosphate'}, 'node': 'xu5p__D_c'},
#   {'attrs': {'name': 'Succinate'}, 'node': 'succ_e'},
#   {'attrs': {'name': 'Ethanol'}, 'node': 'etoh_c'},
#   {'attrs': {'name': 'L-Malate'}, 'node': 'mal__L_e'},
#   {'attrs': {'name': 'Phosphoenolpyruvate'}, 'node': 'pep_c'},
#   {'attrs': {'name': 'Phosphate'}, 'node': 'pi_e'},
#   {'attrs': {'name': 'Cis-Aconitate'}, 'node': 'acon_C_c'},
#   {'attrs': {'name': 'CO2 CO2'}, 'node': 'co2_c'},
#   {'attrs': {'name': 'Ammonium'}, 'node': 'nh4_e'},
#   {'attrs': {'name': 'Dihydroxyacetone phosphate'}, 'node': 'dhap_c'},
#   {'attrs': {'name': '2-Oxoglutarate'}, 'node': 'akg_c'},
#   {'attrs': {'name': '2-Oxoglutarate'}, 'node': 'akg_e'},
#   {'attrs': {'name': 'Phosphate'}, 'node': 'pi_c'},
#   {'attrs': {'name': 'Ubiquinol-8'}, 'node': 'q8h2_c'},
#   {'attrs': {'name': 'Pyruvate'}, 'node': 'pyr_c'},
#   {'attrs': {'name': 'Acetate'}, 'node': 'ac_c'},
#   {'attrs': {'name': 'Isocitrate'}, 'node': 'icit_c'},
#   {'attrs': {'name': 'Nicotinamide adenine dinucleotide phosphate - reduced'},
#    'node': 'nadph_c'},
#   {'attrs': {'name': 'H2O H2O'}, 'node': 'h2o_e'},
#   {'attrs': {'name': 'D-Glucose'}, 'node': 'glc__D_e'},
#   {'attrs': {'name': 'Acetyl-CoA'}, 'node': 'accoa_c'},
#   {'attrs': {'name': 'D-Glucose 6-phosphate'}, 'node': 'g6p_c'},
#   {'attrs': {'name': '3-Phospho-D-glyceroyl phosphate'}, 'node': '13dpg_c'},
#   {'attrs': {'name': 'D-Fructose'}, 'node': 'fru_e'},
#   {'attrs': {'name': 'Pyruvate'}, 'node': 'pyr_e'},
#   {'attrs': {'name': 'Sedoheptulose 7-phosphate'}, 'node': 's7p_c'},
#   {'attrs': {'name': 'Glyoxylate'}, 'node': 'glx_c'},
#   {'attrs': {'name': 'Nicotinamide adenine dinucleotide phosphate'},
#    'node': 'nadp_c'},
#   {'attrs': {'name': 'H2O H2O'}, 'node': 'h2o_c'},
#   {'attrs': {'name': 'Nicotinamide adenine dinucleotide - reduced'},
#    'node': 'nadh_c'},
#   {'attrs': {'name': 'D-Lactate'}, 'node': 'lac__D_c'},
#   {'attrs': {'name': 'Fumarate'}, 'node': 'fum_e'},
#   {'attrs': {'name': 'Ethanol'}, 'node': 'etoh_e'},
#   {'attrs': {'name': 'L-Glutamate'}, 'node': 'glu__L_e'},
#   {'attrs': {'name': 'D-Erythrose 4-phosphate'}, 'node': 'e4p_c'},
#   {'attrs': {'name': 'Citrate'}, 'node': 'cit_c'},
#   {'attrs': {'name': 'Succinate'}, 'node': 'succ_c'},
#   {'attrs': {'name': 'Formate'}, 'node': 'for_c'},
#   {'attrs': {'name': 'ADP C10H12N5O10P2'}, 'node': 'adp_c'},
#   {'attrs': {'name': 'ATP C10H12N5O13P3'}, 'node': 'atp_c'},
#   {'attrs': {'name': 'Ammonium'}, 'node': 'nh4_c'},
#   {'attrs': {'name': 'H+'}, 'node': 'h_c'},
#   {'attrs': {'name': 'H+'}, 'node': 'h_e'}],
#  'edges': [{'attrs': {'name': 'L glutamate transport via proton symport  reversible'},
#    'edge': 'GLUt2r'},
#   {'attrs': {'name': 'Isocitrate dehydrogenase (NADP)'},
#    'edge': 'ICDHyr_reverse'},
#   {'attrs': {'name': 'Glyceraldehyde-3-phosphate dehydrogenase'},
#    'edge': 'GAPD'},
#   {'attrs': {'name': 'Malate synthase'}, 'edge': 'MALS'},
#   {'attrs': {'name': 'Malate dehydrogenase'}, 'edge': 'MDH_reverse'},
#   {'attrs': {'name': 'Glucose 6-phosphate dehydrogenase'},
#    'edge': 'G6PDH2r_reverse'},
#   {'attrs': {'name': 'Transketolase'}, 'edge': 'TKT1_reverse'},
#   {'attrs': {'name': 'D-lactate dehydrogenase'}, 'edge': 'LDH_D_reverse'},
#   {'attrs': {'name': 'Succinate exchange'}, 'edge': 'EX_succ_e'},
#   {'attrs': {'name': '6-phosphogluconolactonase'}, 'edge': 'PGL'},
#   {'attrs': {'name': 'Succinyl-CoA synthetase (ADP-forming)'},
#    'edge': 'SUCOAS_reverse'},
#   {'attrs': {'name': 'Ethanol reversible transport via proton symport'},
#    'edge': 'ETOHt2r'},
#   {'attrs': {'name': 'Fumarate reductase'}, 'edge': 'FRD7'},
#   {'attrs': {'name': 'Malate dehydrogenase'}, 'edge': 'MDH'},
#   {'attrs': {'name': 'Glucose-6-phosphate isomerase'}, 'edge': 'PGI'},
#   {'attrs': {'name': 'L-Glutamine exchange'}, 'edge': 'EX_gln__L_e'},
#   {'attrs': {'name': 'Phosphoenolpyruvate carboxylase'}, 'edge': 'PPC'},
#   {'attrs': {'name': 'H+ exchange'}, 'edge': 'EX_h_e_reverse'},
#   {'attrs': {'name': 'Alcohol dehydrogenase (ethanol)'},
#    'edge': 'ALCD2x_reverse'},
#   {'attrs': {'name': 'Phosphogluconate dehydrogenase'}, 'edge': 'GND'},
#   {'attrs': {'name': 'Fructose-bisphosphate aldolase'}, 'edge': 'FBA_reverse'},
#   {'attrs': {'name': 'Pyruvate dehydrogenase'}, 'edge': 'PDH'},
#   {'attrs': {'name': 'Acetate exchange'}, 'edge': 'EX_ac_e'},
#   {'attrs': {'name': 'Ammonia exchange'}, 'edge': 'EX_nh4_e_reverse'},
#   {'attrs': {'name': 'Glyceraldehyde-3-phosphate dehydrogenase'},
#    'edge': 'GAPD_reverse'},
#   {'attrs': {'name': 'Acetaldehyde dehydrogenase (acetylating)'},
#    'edge': 'ACALD'},
#   {'attrs': {'name': 'D-Glucose exchange'}, 'edge': 'EX_glc__D_e'},
#   {'attrs': {'name': 'Acetate kinase'}, 'edge': 'ACKr_reverse'},
#   {'attrs': {'name': '2-Oxoglutarate exchange'}, 'edge': 'EX_akg_e'},
#   {'attrs': {'name': 'Fructose-bisphosphatase'}, 'edge': 'FBP'},
#   {'attrs': {'name': 'O2 transport  diffusion '}, 'edge': 'O2t_reverse'},
#   {'attrs': {'name': 'H+ exchange'}, 'edge': 'EX_h_e'},
#   {'attrs': {'name': 'L-Glutamate exchange'}, 'edge': 'EX_glu__L_e'},
#   {'attrs': {'name': 'Pyruvate transport in via proton symport'},
#    'edge': 'PYRt2_reverse'},
#   {'attrs': {'name': 'L glutamate transport via proton symport  reversible'},
#    'edge': 'GLUt2r_reverse'},
#   {'attrs': {'name': '2-Oxogluterate dehydrogenase'}, 'edge': 'AKGDH'},
#   {'attrs': {'name': 'Acetate kinase'}, 'edge': 'ACKr'},
#   {'attrs': {'name': 'Ethanol reversible transport via proton symport'},
#    'edge': 'ETOHt2r_reverse'},
#   {'attrs': {'name': 'NADH dehydrogenase (ubiquinone-8 & 3 protons)'},
#    'edge': 'NADH16'},
#   {'attrs': {'name': 'Acetaldehyde exchange'}, 'edge': 'EX_acald_e'},
#   {'attrs': {'name': 'Triose-phosphate isomerase'}, 'edge': 'TPI'},
#   {'attrs': {'name': 'Acetaldehyde dehydrogenase (acetylating)'},
#    'edge': 'ACALD_reverse'},
#   {'attrs': {'name': 'Aconitase (half-reaction A, Citrate hydro-lyase)'},
#    'edge': 'ACONTa_reverse'},
#   {'attrs': {'name': 'Pyruvate exchange'}, 'edge': 'EX_pyr_e'},
#   {'attrs': {'name': 'Acetate reversible transport via proton symport'},
#    'edge': 'ACt2r'},
#   {'attrs': {'name': 'O2 exchange'}, 'edge': 'EX_o2_e'},
#   {'attrs': {'name': 'Pyruvate kinase'}, 'edge': 'PYK'},
#   {'attrs': {'name': 'Pyruvate formate lyase'}, 'edge': 'PFL'},
#   {'attrs': {'name': 'Cytochrome oxidase bd (ubiquinol-8: 2 protons)'},
#    'edge': 'CYTBD'},
#   {'attrs': {'name': 'Glutamine synthetase'}, 'edge': 'GLNS'},
#   {'attrs': {'name': 'Malic enzyme (NADP)'}, 'edge': 'ME2'},
#   {'attrs': {'name': 'Transaldolase'}, 'edge': 'TALA_reverse'},
#   {'attrs': {'name': 'ATP synthase (four protons for one ATP)'},
#    'edge': 'ATPS4r'},
#   {'attrs': {'name': 'O2 exchange'}, 'edge': 'EX_o2_e_reverse'},
#   {'attrs': {'name': 'Phosphoenolpyruvate synthase'}, 'edge': 'PPS'},
#   {'attrs': {'name': 'Fumarate exchange'}, 'edge': 'EX_fum_e'},
#   {'attrs': {'name': 'Phosphotransacetylase'}, 'edge': 'PTAr'},
#   {'attrs': {'name': 'Phosphate reversible transport via symport'},
#    'edge': 'PIt2r'},
#   {'attrs': {'name': 'Isocitrate dehydrogenase (NADP)'}, 'edge': 'ICDHyr'},
#   {'attrs': {'name': 'ATP maintenance requirement'}, 'edge': 'ATPM'},
#   {'attrs': {'name': 'CO2 exchange'}, 'edge': 'EX_co2_e_reverse'},
#   {'attrs': {'name': 'O2 transport  diffusion '}, 'edge': 'O2t'},
#   {'attrs': {'name': 'Aconitase (half-reaction B, Isocitrate hydro-lyase)'},
#    'edge': 'ACONTb_reverse'},
#   {'attrs': {'name': 'H2O exchange'}, 'edge': 'EX_h2o_e_reverse'},
#   {'attrs': {'name': 'L-glutamine transport via ABC system'},
#    'edge': 'GLNabc'},
#   {'attrs': {'name': 'Glutamate dehydrogenase (NADP)'}, 'edge': 'GLUDy'},
#   {'attrs': {'name': 'D-Fructose exchange'}, 'edge': 'EX_fru_e'},
#   {'attrs': {'name': 'Malic enzyme (NAD)'}, 'edge': 'ME1'},
#   {'attrs': {'name': 'Transaldolase'}, 'edge': 'TALA'},
#   {'attrs': {'name': 'Phosphotransacetylase'}, 'edge': 'PTAr_reverse'},
#   {'attrs': {'name': 'D-lactate dehydrogenase'}, 'edge': 'LDH_D'},
#   {'attrs': {'name': 'Ammonia reversible transport'}, 'edge': 'NH4t_reverse'},
#   {'attrs': {'name': 'Phosphate exchange'}, 'edge': 'EX_pi_e_reverse'},
#   {'attrs': {'name': 'Ammonia exchange'}, 'edge': 'EX_nh4_e'},
#   {'attrs': {'name': 'Phosphoglycerate kinase'}, 'edge': 'PGK'},
#   {'attrs': {'name': 'Glucose-6-phosphate isomerase'}, 'edge': 'PGI_reverse'},
#   {'attrs': {'name': 'H2O transport via diffusion'}, 'edge': 'H2Ot_reverse'},
#   {'attrs': {'name': 'Glutaminase'}, 'edge': 'GLUN'},
#   {'attrs': {'name': 'Succinate transport via proton symport (2 H)'},
#    'edge': 'SUCCt2_2'},
#   {'attrs': {'name': 'Acetaldehyde reversible transport'},
#    'edge': 'ACALDt_reverse'},
#   {'attrs': {'name': 'D-Glucose exchange'}, 'edge': 'EX_glc__D_e_reverse'},
#   {'attrs': {'name': 'Glucose 6-phosphate dehydrogenase'}, 'edge': 'G6PDH2r'},
#   {'attrs': {'name': 'Phosphoenolpyruvate carboxykinase'}, 'edge': 'PPCK'},
#   {'attrs': {'name': 'Acetaldehyde reversible transport'}, 'edge': 'ACALDt'},
#   {'attrs': {'name': 'Formate transport in via proton symport'},
#    'edge': 'FORt2'},
#   {'attrs': {'name': 'H2O transport via diffusion'}, 'edge': 'H2Ot'},
#   {'attrs': {'name': 'Adenylate kinase'}, 'edge': 'ADK1'},
#   {'attrs': {'name': 'Fumarase'}, 'edge': 'FUM_reverse'},
#   {'attrs': {'name': 'Transketolase'}, 'edge': 'TKT1'},
#   {'attrs': {'name': 'Isocitrate lyase'}, 'edge': 'ICL'},
#   {'attrs': {'name': 'Fumarate transport via proton symport (2 H)'},
#    'edge': 'FUMt2_2'},
#   {'attrs': {'name': 'CO2 exchange'}, 'edge': 'EX_co2_e'},
#   {'attrs': {'name': 'Phosphoglycerate kinase'}, 'edge': 'PGK_reverse'},
#   {'attrs': {'name': 'Phosphofructokinase'}, 'edge': 'PFK'},
#   {'attrs': {'name': '2 oxoglutarate reversible transport via symport'},
#    'edge': 'AKGt2r'},
#   {'attrs': {'name': 'Phosphate reversible transport via symport'},
#    'edge': 'PIt2r_reverse'},
#   {'attrs': {'name': 'Glutamate synthase (NADPH)'}, 'edge': 'GLUSy'},
#   {'attrs': {'name': 'Phosphoglycerate mutase'}, 'edge': 'PGM_reverse'},
#   {'attrs': {'name': 'Adenylate kinase'}, 'edge': 'ADK1_reverse'},
#   {'attrs': {'name': 'ATP synthase (four protons for one ATP)'},
#    'edge': 'ATPS4r_reverse'},
#   {'attrs': {'name': 'D lactate transport via proton symport'},
#    'edge': 'D_LACt2_reverse'},
#   {'attrs': {'name': 'Enolase'}, 'edge': 'ENO'},
#   {'attrs': {'name': 'Transketolase'}, 'edge': 'TKT2'},
#   {'attrs': {'name': 'Alcohol dehydrogenase (ethanol)'}, 'edge': 'ALCD2x'},
#   {'attrs': {'name': 'Ribulose 5-phosphate 3-epimerase'}, 'edge': 'RPE'},
#   {'attrs': {'name': 'Triose-phosphate isomerase'}, 'edge': 'TPI_reverse'},
#   {'attrs': {'name': 'Malate transport via proton symport (2 H)'},
#    'edge': 'MALt2_2'},
#   {'attrs': {'name': 'Formate exchange'}, 'edge': 'EX_for_e'},
#   {'attrs': {'name': 'D lactate transport via proton symport'},
#    'edge': 'D_LACt2'},
#   {'attrs': {'name': 'Phosphoglycerate mutase'}, 'edge': 'PGM'},
#   {'attrs': {'name': 'L-Malate exchange'}, 'edge': 'EX_mal__L_e'},
#   {'attrs': {'name': 'Formate transport via diffusion'}, 'edge': 'FORt'},
#   {'attrs': {'name': 'Fructose transport via PEP:Pyr PTS (f6p generating)'},
#    'edge': 'FRUpts2'},
#   {'attrs': {'name': 'CO2 transporter via diffusion'}, 'edge': 'CO2t'},
#   {'attrs': {'name': 'Ribose-5-phosphate isomerase'}, 'edge': 'RPI'},
#   {'attrs': {'name': 'Fructose-bisphosphate aldolase'}, 'edge': 'FBA'},
#   {'attrs': {'name': 'Ribulose 5-phosphate 3-epimerase'},
#    'edge': 'RPE_reverse'},
#   {'attrs': {'name': 'D-glucose transport via PEP:Pyr PTS'}, 'edge': 'GLCpts'},
#   {'attrs': {'name': 'Fumarase'}, 'edge': 'FUM'},
#   {'attrs': {'name': 'Ethanol exchange'}, 'edge': 'EX_etoh_e'},
#   {'attrs': {'name': 'Succinate transport out via proton antiport'},
#    'edge': 'SUCCt3'},
#   {'attrs': {'name': 'Aconitase (half-reaction B, Isocitrate hydro-lyase)'},
#    'edge': 'ACONTb'},
#   {'attrs': {'name': 'Transketolase'}, 'edge': 'TKT2_reverse'},
#   {'attrs': {'name': 'NAD(P) transhydrogenase'}, 'edge': 'THD2'},
#   {'attrs': {'name': 'Glutamate dehydrogenase (NADP)'},
#    'edge': 'GLUDy_reverse'},
#   {'attrs': {'name': 'Biomass Objective Function with GAM'},
#    'edge': 'BIOMASS_Ecoli_core_w_GAM'},
#   {'attrs': {'name': 'Ammonia reversible transport'}, 'edge': 'NH4t'},
#   {'attrs': {'name': 'Ribose-5-phosphate isomerase'}, 'edge': 'RPI_reverse'},
#   {'attrs': {'name': 'Succinyl-CoA synthetase (ADP-forming)'},
#    'edge': 'SUCOAS'},
#   {'attrs': {'name': 'D-lactate exchange'}, 'edge': 'EX_lac__D_e'},
#   {'attrs': {'name': 'Enolase'}, 'edge': 'ENO_reverse'},
#   {'attrs': {'name': 'CO2 transporter via diffusion'}, 'edge': 'CO2t_reverse'},
#   {'attrs': {'name': 'NAD transhydrogenase'}, 'edge': 'NADTRHD'},
#   {'attrs': {'name': 'Phosphate exchange'}, 'edge': 'EX_pi_e'},
#   {'attrs': {'name': '2 oxoglutarate reversible transport via symport'},
#    'edge': 'AKGt2r_reverse'},
#   {'attrs': {'name': 'Aconitase (half-reaction A, Citrate hydro-lyase)'},
#    'edge': 'ACONTa'},
#   {'attrs': {'name': 'H2O exchange'}, 'edge': 'EX_h2o_e'},
#   {'attrs': {'name': 'Acetate reversible transport via proton symport'},
#    'edge': 'ACt2r_reverse'},
#   {'attrs': {'name': 'Pyruvate transport in via proton symport'},
#    'edge': 'PYRt2'},
#   {'attrs': {'name': 'Succinate dehydrogenase (irreversible)'},
#    'edge': 'SUCDi'},
#   {'attrs': {'name': 'Citrate synthase'}, 'edge': 'CS'}],
#  'incidences': [{'edge': 'PFK', 'node': 'f6p_c', 'direction': 'tail'},
#   {'edge': 'PFK', 'node': 'atp_c', 'direction': 'tail'},
#   {'edge': 'PFK', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'PFK', 'node': 'adp_c', 'direction': 'head'},
#   {'edge': 'PFK', 'node': 'fdp_c', 'direction': 'head'},
#   {'edge': 'PFL', 'node': 'coa_c', 'direction': 'tail'},
#   {'edge': 'PFL', 'node': 'pyr_c', 'direction': 'tail'},
#   {'edge': 'PFL', 'node': 'accoa_c', 'direction': 'head'},
#   {'edge': 'PFL', 'node': 'for_c', 'direction': 'head'},
#   {'edge': 'PGI', 'node': 'g6p_c', 'direction': 'tail'},
#   {'edge': 'PGI', 'node': 'f6p_c', 'direction': 'head'},
#   {'edge': 'PGI_reverse', 'node': 'f6p_c', 'direction': 'tail'},
#   {'edge': 'PGI_reverse', 'node': 'g6p_c', 'direction': 'head'},
#   {'edge': 'PGK', 'node': '3pg_c', 'direction': 'tail'},
#   {'edge': 'PGK', 'node': 'atp_c', 'direction': 'tail'},
#   {'edge': 'PGK', 'node': 'adp_c', 'direction': 'head'},
#   {'edge': 'PGK', 'node': '13dpg_c', 'direction': 'head'},
#   {'edge': 'PGK_reverse', 'node': 'adp_c', 'direction': 'tail'},
#   {'edge': 'PGK_reverse', 'node': '13dpg_c', 'direction': 'tail'},
#   {'edge': 'PGK_reverse', 'node': '3pg_c', 'direction': 'head'},
#   {'edge': 'PGK_reverse', 'node': 'atp_c', 'direction': 'head'},
#   {'edge': 'PGL', 'node': 'h2o_c', 'direction': 'tail'},
#   {'edge': 'PGL', 'node': '6pgl_c', 'direction': 'tail'},
#   {'edge': 'PGL', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'PGL', 'node': '6pgc_c', 'direction': 'head'},
#   {'edge': 'ACALD', 'node': 'coa_c', 'direction': 'tail'},
#   {'edge': 'ACALD', 'node': 'nad_c', 'direction': 'tail'},
#   {'edge': 'ACALD', 'node': 'acald_c', 'direction': 'tail'},
#   {'edge': 'ACALD', 'node': 'accoa_c', 'direction': 'head'},
#   {'edge': 'ACALD', 'node': 'nadh_c', 'direction': 'head'},
#   {'edge': 'ACALD', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'ACALD_reverse', 'node': 'accoa_c', 'direction': 'tail'},
#   {'edge': 'ACALD_reverse', 'node': 'nadh_c', 'direction': 'tail'},
#   {'edge': 'ACALD_reverse', 'node': 'h_c', 'direction': 'tail'},
#   {'edge': 'ACALD_reverse', 'node': 'coa_c', 'direction': 'head'},
#   {'edge': 'ACALD_reverse', 'node': 'nad_c', 'direction': 'head'},
#   {'edge': 'ACALD_reverse', 'node': 'acald_c', 'direction': 'head'},
#   {'edge': 'AKGt2r', 'node': 'akg_e', 'direction': 'tail'},
#   {'edge': 'AKGt2r', 'node': 'h_e', 'direction': 'tail'},
#   {'edge': 'AKGt2r', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'AKGt2r', 'node': 'akg_c', 'direction': 'head'},
#   {'edge': 'AKGt2r_reverse', 'node': 'h_c', 'direction': 'tail'},
#   {'edge': 'AKGt2r_reverse', 'node': 'akg_c', 'direction': 'tail'},
#   {'edge': 'AKGt2r_reverse', 'node': 'akg_e', 'direction': 'head'},
#   {'edge': 'AKGt2r_reverse', 'node': 'h_e', 'direction': 'head'},
#   {'edge': 'PGM', 'node': '2pg_c', 'direction': 'tail'},
#   {'edge': 'PGM', 'node': '3pg_c', 'direction': 'head'},
#   {'edge': 'PGM_reverse', 'node': '3pg_c', 'direction': 'tail'},
#   {'edge': 'PGM_reverse', 'node': '2pg_c', 'direction': 'head'},
#   {'edge': 'PIt2r', 'node': 'h_e', 'direction': 'tail'},
#   {'edge': 'PIt2r', 'node': 'pi_e', 'direction': 'tail'},
#   {'edge': 'PIt2r', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'PIt2r', 'node': 'pi_c', 'direction': 'head'},
#   {'edge': 'PIt2r_reverse', 'node': 'h_c', 'direction': 'tail'},
#   {'edge': 'PIt2r_reverse', 'node': 'pi_c', 'direction': 'tail'},
#   {'edge': 'PIt2r_reverse', 'node': 'h_e', 'direction': 'head'},
#   {'edge': 'PIt2r_reverse', 'node': 'pi_e', 'direction': 'head'},
#   {'edge': 'ALCD2x', 'node': 'etoh_c', 'direction': 'tail'},
#   {'edge': 'ALCD2x', 'node': 'nad_c', 'direction': 'tail'},
#   {'edge': 'ALCD2x', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'ALCD2x', 'node': 'nadh_c', 'direction': 'head'},
#   {'edge': 'ALCD2x', 'node': 'acald_c', 'direction': 'head'},
#   {'edge': 'ALCD2x_reverse', 'node': 'h_c', 'direction': 'tail'},
#   {'edge': 'ALCD2x_reverse', 'node': 'nadh_c', 'direction': 'tail'},
#   {'edge': 'ALCD2x_reverse', 'node': 'acald_c', 'direction': 'tail'},
#   {'edge': 'ALCD2x_reverse', 'node': 'etoh_c', 'direction': 'head'},
#   {'edge': 'ALCD2x_reverse', 'node': 'nad_c', 'direction': 'head'},
#   {'edge': 'ACALDt', 'node': 'acald_e', 'direction': 'tail'},
#   {'edge': 'ACALDt', 'node': 'acald_c', 'direction': 'head'},
#   {'edge': 'ACALDt_reverse', 'node': 'acald_c', 'direction': 'tail'},
#   {'edge': 'ACALDt_reverse', 'node': 'acald_e', 'direction': 'head'},
#   {'edge': 'ACKr', 'node': 'ac_c', 'direction': 'tail'},
#   {'edge': 'ACKr', 'node': 'atp_c', 'direction': 'tail'},
#   {'edge': 'ACKr', 'node': 'adp_c', 'direction': 'head'},
#   {'edge': 'ACKr', 'node': 'actp_c', 'direction': 'head'},
#   {'edge': 'ACKr_reverse', 'node': 'adp_c', 'direction': 'tail'},
#   {'edge': 'ACKr_reverse', 'node': 'actp_c', 'direction': 'tail'},
#   {'edge': 'ACKr_reverse', 'node': 'ac_c', 'direction': 'head'},
#   {'edge': 'ACKr_reverse', 'node': 'atp_c', 'direction': 'head'},
#   {'edge': 'PPC', 'node': 'h2o_c', 'direction': 'tail'},
#   {'edge': 'PPC', 'node': 'co2_c', 'direction': 'tail'},
#   {'edge': 'PPC', 'node': 'pep_c', 'direction': 'tail'},
#   {'edge': 'PPC', 'node': 'oaa_c', 'direction': 'head'},
#   {'edge': 'PPC', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'PPC', 'node': 'pi_c', 'direction': 'head'},
#   {'edge': 'ACONTa', 'node': 'cit_c', 'direction': 'tail'},
#   {'edge': 'ACONTa', 'node': 'acon_C_c', 'direction': 'head'},
#   {'edge': 'ACONTa', 'node': 'h2o_c', 'direction': 'head'},
#   {'edge': 'ACONTa_reverse', 'node': 'acon_C_c', 'direction': 'tail'},
#   {'edge': 'ACONTa_reverse', 'node': 'h2o_c', 'direction': 'tail'},
#   {'edge': 'ACONTa_reverse', 'node': 'cit_c', 'direction': 'head'},
#   {'edge': 'ACONTb', 'node': 'acon_C_c', 'direction': 'tail'},
#   {'edge': 'ACONTb', 'node': 'h2o_c', 'direction': 'tail'},
#   {'edge': 'ACONTb', 'node': 'icit_c', 'direction': 'head'},
#   {'edge': 'ACONTb_reverse', 'node': 'icit_c', 'direction': 'tail'},
#   {'edge': 'ACONTb_reverse', 'node': 'acon_C_c', 'direction': 'head'},
#   {'edge': 'ACONTb_reverse', 'node': 'h2o_c', 'direction': 'head'},
#   {'edge': 'ATPM', 'node': 'h2o_c', 'direction': 'tail'},
#   {'edge': 'ATPM', 'node': 'atp_c', 'direction': 'tail'},
#   {'edge': 'ATPM', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'ATPM', 'node': 'pi_c', 'direction': 'head'},
#   {'edge': 'ATPM', 'node': 'adp_c', 'direction': 'head'},
#   {'edge': 'PPCK', 'node': 'oaa_c', 'direction': 'tail'},
#   {'edge': 'PPCK', 'node': 'atp_c', 'direction': 'tail'},
#   {'edge': 'PPCK', 'node': 'pep_c', 'direction': 'head'},
#   {'edge': 'PPCK', 'node': 'co2_c', 'direction': 'head'},
#   {'edge': 'PPCK', 'node': 'adp_c', 'direction': 'head'},
#   {'edge': 'ACt2r', 'node': 'ac_e', 'direction': 'tail'},
#   {'edge': 'ACt2r', 'node': 'h_e', 'direction': 'tail'},
#   {'edge': 'ACt2r', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'ACt2r', 'node': 'ac_c', 'direction': 'head'},
#   {'edge': 'ACt2r_reverse', 'node': 'h_c', 'direction': 'tail'},
#   {'edge': 'ACt2r_reverse', 'node': 'ac_c', 'direction': 'tail'},
#   {'edge': 'ACt2r_reverse', 'node': 'ac_e', 'direction': 'head'},
#   {'edge': 'ACt2r_reverse', 'node': 'h_e', 'direction': 'head'},
#   {'edge': 'PPS', 'node': 'h2o_c', 'direction': 'tail'},
#   {'edge': 'PPS', 'node': 'pyr_c', 'direction': 'tail'},
#   {'edge': 'PPS', 'node': 'atp_c', 'direction': 'tail'},
#   {'edge': 'PPS', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'PPS', 'node': 'pi_c', 'direction': 'head'},
#   {'edge': 'PPS', 'node': 'pep_c', 'direction': 'head'},
#   {'edge': 'PPS', 'node': 'amp_c', 'direction': 'head'},
#   {'edge': 'ADK1', 'node': 'amp_c', 'direction': 'tail'},
#   {'edge': 'ADK1', 'node': 'atp_c', 'direction': 'tail'},
#   {'edge': 'ADK1', 'node': 'adp_c', 'direction': 'head'},
#   {'edge': 'ADK1_reverse', 'node': 'adp_c', 'direction': 'tail'},
#   {'edge': 'ADK1_reverse', 'node': 'amp_c', 'direction': 'head'},
#   {'edge': 'ADK1_reverse', 'node': 'atp_c', 'direction': 'head'},
#   {'edge': 'AKGDH', 'node': 'coa_c', 'direction': 'tail'},
#   {'edge': 'AKGDH', 'node': 'akg_c', 'direction': 'tail'},
#   {'edge': 'AKGDH', 'node': 'nad_c', 'direction': 'tail'},
#   {'edge': 'AKGDH', 'node': 'co2_c', 'direction': 'head'},
#   {'edge': 'AKGDH', 'node': 'nadh_c', 'direction': 'head'},
#   {'edge': 'AKGDH', 'node': 'succoa_c', 'direction': 'head'},
#   {'edge': 'ATPS4r', 'node': 'pi_c', 'direction': 'tail'},
#   {'edge': 'ATPS4r', 'node': 'adp_c', 'direction': 'tail'},
#   {'edge': 'ATPS4r', 'node': 'h_e', 'direction': 'tail'},
#   {'edge': 'ATPS4r', 'node': 'h2o_c', 'direction': 'head'},
#   {'edge': 'ATPS4r', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'ATPS4r', 'node': 'atp_c', 'direction': 'head'},
#   {'edge': 'ATPS4r_reverse', 'node': 'h2o_c', 'direction': 'tail'},
#   {'edge': 'ATPS4r_reverse', 'node': 'h_c', 'direction': 'tail'},
#   {'edge': 'ATPS4r_reverse', 'node': 'atp_c', 'direction': 'tail'},
#   {'edge': 'ATPS4r_reverse', 'node': 'pi_c', 'direction': 'head'},
#   {'edge': 'ATPS4r_reverse', 'node': 'adp_c', 'direction': 'head'},
#   {'edge': 'ATPS4r_reverse', 'node': 'h_e', 'direction': 'head'},
#   {'edge': 'PTAr', 'node': 'accoa_c', 'direction': 'tail'},
#   {'edge': 'PTAr', 'node': 'pi_c', 'direction': 'tail'},
#   {'edge': 'PTAr', 'node': 'coa_c', 'direction': 'head'},
#   {'edge': 'PTAr', 'node': 'actp_c', 'direction': 'head'},
#   {'edge': 'PTAr_reverse', 'node': 'coa_c', 'direction': 'tail'},
#   {'edge': 'PTAr_reverse', 'node': 'actp_c', 'direction': 'tail'},
#   {'edge': 'PTAr_reverse', 'node': 'accoa_c', 'direction': 'head'},
#   {'edge': 'PTAr_reverse', 'node': 'pi_c', 'direction': 'head'},
#   {'edge': 'PYK', 'node': 'h_c', 'direction': 'tail'},
#   {'edge': 'PYK', 'node': 'pep_c', 'direction': 'tail'},
#   {'edge': 'PYK', 'node': 'adp_c', 'direction': 'tail'},
#   {'edge': 'PYK', 'node': 'pyr_c', 'direction': 'head'},
#   {'edge': 'PYK', 'node': 'atp_c', 'direction': 'head'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM',
#    'node': 'gln__L_c',
#    'direction': 'tail'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': 'pyr_c', 'direction': 'tail'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': '3pg_c', 'direction': 'tail'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM',
#    'node': 'glu__L_c',
#    'direction': 'tail'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': 'nadph_c', 'direction': 'tail'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': 'nad_c', 'direction': 'tail'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': 'atp_c', 'direction': 'tail'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': 'accoa_c', 'direction': 'tail'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': 'f6p_c', 'direction': 'tail'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': 'g3p_c', 'direction': 'tail'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': 'h2o_c', 'direction': 'tail'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': 'g6p_c', 'direction': 'tail'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': 'pep_c', 'direction': 'tail'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': 'r5p_c', 'direction': 'tail'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': 'oaa_c', 'direction': 'tail'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': 'e4p_c', 'direction': 'tail'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': 'akg_c', 'direction': 'head'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': 'adp_c', 'direction': 'head'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': 'nadp_c', 'direction': 'head'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': 'coa_c', 'direction': 'head'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': 'pi_c', 'direction': 'head'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': 'nadh_c', 'direction': 'head'},
#   {'edge': 'BIOMASS_Ecoli_core_w_GAM', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'PYRt2', 'node': 'pyr_e', 'direction': 'tail'},
#   {'edge': 'PYRt2', 'node': 'h_e', 'direction': 'tail'},
#   {'edge': 'PYRt2', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'PYRt2', 'node': 'pyr_c', 'direction': 'head'},
#   {'edge': 'PYRt2_reverse', 'node': 'h_c', 'direction': 'tail'},
#   {'edge': 'PYRt2_reverse', 'node': 'pyr_c', 'direction': 'tail'},
#   {'edge': 'PYRt2_reverse', 'node': 'pyr_e', 'direction': 'head'},
#   {'edge': 'PYRt2_reverse', 'node': 'h_e', 'direction': 'head'},
#   {'edge': 'CO2t', 'node': 'co2_e', 'direction': 'tail'},
#   {'edge': 'CO2t', 'node': 'co2_c', 'direction': 'head'},
#   {'edge': 'CO2t_reverse', 'node': 'co2_c', 'direction': 'tail'},
#   {'edge': 'CO2t_reverse', 'node': 'co2_e', 'direction': 'head'},
#   {'edge': 'RPE', 'node': 'ru5p__D_c', 'direction': 'tail'},
#   {'edge': 'RPE', 'node': 'xu5p__D_c', 'direction': 'head'},
#   {'edge': 'RPE_reverse', 'node': 'xu5p__D_c', 'direction': 'tail'},
#   {'edge': 'RPE_reverse', 'node': 'ru5p__D_c', 'direction': 'head'},
#   {'edge': 'CS', 'node': 'oaa_c', 'direction': 'tail'},
#   {'edge': 'CS', 'node': 'accoa_c', 'direction': 'tail'},
#   {'edge': 'CS', 'node': 'h2o_c', 'direction': 'tail'},
#   {'edge': 'CS', 'node': 'cit_c', 'direction': 'head'},
#   {'edge': 'CS', 'node': 'coa_c', 'direction': 'head'},
#   {'edge': 'CS', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'RPI', 'node': 'r5p_c', 'direction': 'tail'},
#   {'edge': 'RPI', 'node': 'ru5p__D_c', 'direction': 'head'},
#   {'edge': 'RPI_reverse', 'node': 'ru5p__D_c', 'direction': 'tail'},
#   {'edge': 'RPI_reverse', 'node': 'r5p_c', 'direction': 'head'},
#   {'edge': 'SUCCt2_2', 'node': 'succ_e', 'direction': 'tail'},
#   {'edge': 'SUCCt2_2', 'node': 'h_e', 'direction': 'tail'},
#   {'edge': 'SUCCt2_2', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'SUCCt2_2', 'node': 'succ_c', 'direction': 'head'},
#   {'edge': 'CYTBD', 'node': 'h_c', 'direction': 'tail'},
#   {'edge': 'CYTBD', 'node': 'o2_c', 'direction': 'tail'},
#   {'edge': 'CYTBD', 'node': 'q8h2_c', 'direction': 'tail'},
#   {'edge': 'CYTBD', 'node': 'h2o_c', 'direction': 'head'},
#   {'edge': 'CYTBD', 'node': 'h_e', 'direction': 'head'},
#   {'edge': 'CYTBD', 'node': 'q8_c', 'direction': 'head'},
#   {'edge': 'D_LACt2', 'node': 'h_e', 'direction': 'tail'},
#   {'edge': 'D_LACt2', 'node': 'lac__D_e', 'direction': 'tail'},
#   {'edge': 'D_LACt2', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'D_LACt2', 'node': 'lac__D_c', 'direction': 'head'},
#   {'edge': 'D_LACt2_reverse', 'node': 'h_c', 'direction': 'tail'},
#   {'edge': 'D_LACt2_reverse', 'node': 'lac__D_c', 'direction': 'tail'},
#   {'edge': 'D_LACt2_reverse', 'node': 'h_e', 'direction': 'head'},
#   {'edge': 'D_LACt2_reverse', 'node': 'lac__D_e', 'direction': 'head'},
#   {'edge': 'ENO', 'node': '2pg_c', 'direction': 'tail'},
#   {'edge': 'ENO', 'node': 'h2o_c', 'direction': 'head'},
#   {'edge': 'ENO', 'node': 'pep_c', 'direction': 'head'},
#   {'edge': 'ENO_reverse', 'node': 'h2o_c', 'direction': 'tail'},
#   {'edge': 'ENO_reverse', 'node': 'pep_c', 'direction': 'tail'},
#   {'edge': 'ENO_reverse', 'node': '2pg_c', 'direction': 'head'},
#   {'edge': 'SUCCt3', 'node': 'succ_c', 'direction': 'tail'},
#   {'edge': 'SUCCt3', 'node': 'h_e', 'direction': 'tail'},
#   {'edge': 'SUCCt3', 'node': 'succ_e', 'direction': 'head'},
#   {'edge': 'SUCCt3', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'ETOHt2r', 'node': 'etoh_e', 'direction': 'tail'},
#   {'edge': 'ETOHt2r', 'node': 'h_e', 'direction': 'tail'},
#   {'edge': 'ETOHt2r', 'node': 'etoh_c', 'direction': 'head'},
#   {'edge': 'ETOHt2r', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'ETOHt2r_reverse', 'node': 'etoh_c', 'direction': 'tail'},
#   {'edge': 'ETOHt2r_reverse', 'node': 'h_c', 'direction': 'tail'},
#   {'edge': 'ETOHt2r_reverse', 'node': 'etoh_e', 'direction': 'head'},
#   {'edge': 'ETOHt2r_reverse', 'node': 'h_e', 'direction': 'head'},
#   {'edge': 'SUCDi', 'node': 'succ_c', 'direction': 'tail'},
#   {'edge': 'SUCDi', 'node': 'q8_c', 'direction': 'tail'},
#   {'edge': 'SUCDi', 'node': 'fum_c', 'direction': 'head'},
#   {'edge': 'SUCDi', 'node': 'q8h2_c', 'direction': 'head'},
#   {'edge': 'SUCOAS', 'node': 'coa_c', 'direction': 'tail'},
#   {'edge': 'SUCOAS', 'node': 'succ_c', 'direction': 'tail'},
#   {'edge': 'SUCOAS', 'node': 'atp_c', 'direction': 'tail'},
#   {'edge': 'SUCOAS', 'node': 'pi_c', 'direction': 'head'},
#   {'edge': 'SUCOAS', 'node': 'adp_c', 'direction': 'head'},
#   {'edge': 'SUCOAS', 'node': 'succoa_c', 'direction': 'head'},
#   {'edge': 'SUCOAS_reverse', 'node': 'pi_c', 'direction': 'tail'},
#   {'edge': 'SUCOAS_reverse', 'node': 'adp_c', 'direction': 'tail'},
#   {'edge': 'SUCOAS_reverse', 'node': 'succoa_c', 'direction': 'tail'},
#   {'edge': 'SUCOAS_reverse', 'node': 'coa_c', 'direction': 'head'},
#   {'edge': 'SUCOAS_reverse', 'node': 'succ_c', 'direction': 'head'},
#   {'edge': 'SUCOAS_reverse', 'node': 'atp_c', 'direction': 'head'},
#   {'edge': 'TALA', 'node': 's7p_c', 'direction': 'tail'},
#   {'edge': 'TALA', 'node': 'g3p_c', 'direction': 'tail'},
#   {'edge': 'TALA', 'node': 'f6p_c', 'direction': 'head'},
#   {'edge': 'TALA', 'node': 'e4p_c', 'direction': 'head'},
#   {'edge': 'TALA_reverse', 'node': 'f6p_c', 'direction': 'tail'},
#   {'edge': 'TALA_reverse', 'node': 'e4p_c', 'direction': 'tail'},
#   {'edge': 'TALA_reverse', 'node': 's7p_c', 'direction': 'head'},
#   {'edge': 'TALA_reverse', 'node': 'g3p_c', 'direction': 'head'},
#   {'edge': 'THD2', 'node': 'nadh_c', 'direction': 'tail'},
#   {'edge': 'THD2', 'node': 'h_e', 'direction': 'tail'},
#   {'edge': 'THD2', 'node': 'nadp_c', 'direction': 'tail'},
#   {'edge': 'THD2', 'node': 'nadph_c', 'direction': 'head'},
#   {'edge': 'THD2', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'THD2', 'node': 'nad_c', 'direction': 'head'},
#   {'edge': 'TKT1', 'node': 'r5p_c', 'direction': 'tail'},
#   {'edge': 'TKT1', 'node': 'xu5p__D_c', 'direction': 'tail'},
#   {'edge': 'TKT1', 'node': 's7p_c', 'direction': 'head'},
#   {'edge': 'TKT1', 'node': 'g3p_c', 'direction': 'head'},
#   {'edge': 'TKT1_reverse', 'node': 's7p_c', 'direction': 'tail'},
#   {'edge': 'TKT1_reverse', 'node': 'g3p_c', 'direction': 'tail'},
#   {'edge': 'TKT1_reverse', 'node': 'r5p_c', 'direction': 'head'},
#   {'edge': 'TKT1_reverse', 'node': 'xu5p__D_c', 'direction': 'head'},
#   {'edge': 'TKT2', 'node': 'e4p_c', 'direction': 'tail'},
#   {'edge': 'TKT2', 'node': 'xu5p__D_c', 'direction': 'tail'},
#   {'edge': 'TKT2', 'node': 'f6p_c', 'direction': 'head'},
#   {'edge': 'TKT2', 'node': 'g3p_c', 'direction': 'head'},
#   {'edge': 'TKT2_reverse', 'node': 'f6p_c', 'direction': 'tail'},
#   {'edge': 'TKT2_reverse', 'node': 'g3p_c', 'direction': 'tail'},
#   {'edge': 'TKT2_reverse', 'node': 'e4p_c', 'direction': 'head'},
#   {'edge': 'TKT2_reverse', 'node': 'xu5p__D_c', 'direction': 'head'},
#   {'edge': 'TPI', 'node': 'dhap_c', 'direction': 'tail'},
#   {'edge': 'TPI', 'node': 'g3p_c', 'direction': 'head'},
#   {'edge': 'TPI_reverse', 'node': 'g3p_c', 'direction': 'tail'},
#   {'edge': 'TPI_reverse', 'node': 'dhap_c', 'direction': 'head'},
#   {'edge': 'EX_ac_e', 'node': 'ac_e', 'direction': 'tail'},
#   {'edge': 'EX_acald_e', 'node': 'acald_e', 'direction': 'tail'},
#   {'edge': 'EX_akg_e', 'node': 'akg_e', 'direction': 'tail'},
#   {'edge': 'EX_co2_e', 'node': 'co2_e', 'direction': 'tail'},
#   {'edge': 'EX_co2_e_reverse', 'node': 'co2_e', 'direction': 'head'},
#   {'edge': 'EX_etoh_e', 'node': 'etoh_e', 'direction': 'tail'},
#   {'edge': 'EX_for_e', 'node': 'for_e', 'direction': 'tail'},
#   {'edge': 'EX_fru_e', 'node': 'fru_e', 'direction': 'tail'},
#   {'edge': 'EX_fum_e', 'node': 'fum_e', 'direction': 'tail'},
#   {'edge': 'EX_glc__D_e', 'node': 'glc__D_e', 'direction': 'tail'},
#   {'edge': 'EX_glc__D_e_reverse', 'node': 'glc__D_e', 'direction': 'head'},
#   {'edge': 'EX_gln__L_e', 'node': 'gln__L_e', 'direction': 'tail'},
#   {'edge': 'EX_glu__L_e', 'node': 'glu__L_e', 'direction': 'tail'},
#   {'edge': 'EX_h_e', 'node': 'h_e', 'direction': 'tail'},
#   {'edge': 'EX_h_e_reverse', 'node': 'h_e', 'direction': 'head'},
#   {'edge': 'EX_h2o_e', 'node': 'h2o_e', 'direction': 'tail'},
#   {'edge': 'EX_h2o_e_reverse', 'node': 'h2o_e', 'direction': 'head'},
#   {'edge': 'EX_lac__D_e', 'node': 'lac__D_e', 'direction': 'tail'},
#   {'edge': 'EX_mal__L_e', 'node': 'mal__L_e', 'direction': 'tail'},
#   {'edge': 'EX_nh4_e', 'node': 'nh4_e', 'direction': 'tail'},
#   {'edge': 'EX_nh4_e_reverse', 'node': 'nh4_e', 'direction': 'head'},
#   {'edge': 'EX_o2_e', 'node': 'o2_e', 'direction': 'tail'},
#   {'edge': 'EX_o2_e_reverse', 'node': 'o2_e', 'direction': 'head'},
#   {'edge': 'EX_pi_e', 'node': 'pi_e', 'direction': 'tail'},
#   {'edge': 'EX_pi_e_reverse', 'node': 'pi_e', 'direction': 'head'},
#   {'edge': 'EX_pyr_e', 'node': 'pyr_e', 'direction': 'tail'},
#   {'edge': 'EX_succ_e', 'node': 'succ_e', 'direction': 'tail'},
#   {'edge': 'FBA', 'node': 'fdp_c', 'direction': 'tail'},
#   {'edge': 'FBA', 'node': 'g3p_c', 'direction': 'head'},
#   {'edge': 'FBA', 'node': 'dhap_c', 'direction': 'head'},
#   {'edge': 'FBA_reverse', 'node': 'g3p_c', 'direction': 'tail'},
#   {'edge': 'FBA_reverse', 'node': 'dhap_c', 'direction': 'tail'},
#   {'edge': 'FBA_reverse', 'node': 'fdp_c', 'direction': 'head'},
#   {'edge': 'FBP', 'node': 'h2o_c', 'direction': 'tail'},
#   {'edge': 'FBP', 'node': 'fdp_c', 'direction': 'tail'},
#   {'edge': 'FBP', 'node': 'f6p_c', 'direction': 'head'},
#   {'edge': 'FBP', 'node': 'pi_c', 'direction': 'head'},
#   {'edge': 'FORt2', 'node': 'for_e', 'direction': 'tail'},
#   {'edge': 'FORt2', 'node': 'h_e', 'direction': 'tail'},
#   {'edge': 'FORt2', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'FORt2', 'node': 'for_c', 'direction': 'head'},
#   {'edge': 'FORt', 'node': 'for_c', 'direction': 'tail'},
#   {'edge': 'FORt', 'node': 'for_e', 'direction': 'head'},
#   {'edge': 'FRD7', 'node': 'fum_c', 'direction': 'tail'},
#   {'edge': 'FRD7', 'node': 'q8h2_c', 'direction': 'tail'},
#   {'edge': 'FRD7', 'node': 'succ_c', 'direction': 'head'},
#   {'edge': 'FRD7', 'node': 'q8_c', 'direction': 'head'},
#   {'edge': 'FRUpts2', 'node': 'fru_e', 'direction': 'tail'},
#   {'edge': 'FRUpts2', 'node': 'pep_c', 'direction': 'tail'},
#   {'edge': 'FRUpts2', 'node': 'f6p_c', 'direction': 'head'},
#   {'edge': 'FRUpts2', 'node': 'pyr_c', 'direction': 'head'},
#   {'edge': 'FUM', 'node': 'fum_c', 'direction': 'tail'},
#   {'edge': 'FUM', 'node': 'h2o_c', 'direction': 'tail'},
#   {'edge': 'FUM', 'node': 'mal__L_c', 'direction': 'head'},
#   {'edge': 'FUM_reverse', 'node': 'mal__L_c', 'direction': 'tail'},
#   {'edge': 'FUM_reverse', 'node': 'fum_c', 'direction': 'head'},
#   {'edge': 'FUM_reverse', 'node': 'h2o_c', 'direction': 'head'},
#   {'edge': 'FUMt2_2', 'node': 'h_e', 'direction': 'tail'},
#   {'edge': 'FUMt2_2', 'node': 'fum_e', 'direction': 'tail'},
#   {'edge': 'FUMt2_2', 'node': 'fum_c', 'direction': 'head'},
#   {'edge': 'FUMt2_2', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'G6PDH2r', 'node': 'g6p_c', 'direction': 'tail'},
#   {'edge': 'G6PDH2r', 'node': 'nadp_c', 'direction': 'tail'},
#   {'edge': 'G6PDH2r', 'node': 'nadph_c', 'direction': 'head'},
#   {'edge': 'G6PDH2r', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'G6PDH2r', 'node': '6pgl_c', 'direction': 'head'},
#   {'edge': 'G6PDH2r_reverse', 'node': 'nadph_c', 'direction': 'tail'},
#   {'edge': 'G6PDH2r_reverse', 'node': 'h_c', 'direction': 'tail'},
#   {'edge': 'G6PDH2r_reverse', 'node': '6pgl_c', 'direction': 'tail'},
#   {'edge': 'G6PDH2r_reverse', 'node': 'g6p_c', 'direction': 'head'},
#   {'edge': 'G6PDH2r_reverse', 'node': 'nadp_c', 'direction': 'head'},
#   {'edge': 'GAPD', 'node': 'pi_c', 'direction': 'tail'},
#   {'edge': 'GAPD', 'node': 'nad_c', 'direction': 'tail'},
#   {'edge': 'GAPD', 'node': 'g3p_c', 'direction': 'tail'},
#   {'edge': 'GAPD', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'GAPD', 'node': 'nadh_c', 'direction': 'head'},
#   {'edge': 'GAPD', 'node': '13dpg_c', 'direction': 'head'},
#   {'edge': 'GAPD_reverse', 'node': 'h_c', 'direction': 'tail'},
#   {'edge': 'GAPD_reverse', 'node': 'nadh_c', 'direction': 'tail'},
#   {'edge': 'GAPD_reverse', 'node': '13dpg_c', 'direction': 'tail'},
#   {'edge': 'GAPD_reverse', 'node': 'pi_c', 'direction': 'head'},
#   {'edge': 'GAPD_reverse', 'node': 'nad_c', 'direction': 'head'},
#   {'edge': 'GAPD_reverse', 'node': 'g3p_c', 'direction': 'head'},
#   {'edge': 'GLCpts', 'node': 'glc__D_e', 'direction': 'tail'},
#   {'edge': 'GLCpts', 'node': 'pep_c', 'direction': 'tail'},
#   {'edge': 'GLCpts', 'node': 'g6p_c', 'direction': 'head'},
#   {'edge': 'GLCpts', 'node': 'pyr_c', 'direction': 'head'},
#   {'edge': 'GLNS', 'node': 'glu__L_c', 'direction': 'tail'},
#   {'edge': 'GLNS', 'node': 'nh4_c', 'direction': 'tail'},
#   {'edge': 'GLNS', 'node': 'atp_c', 'direction': 'tail'},
#   {'edge': 'GLNS', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'GLNS', 'node': 'pi_c', 'direction': 'head'},
#   {'edge': 'GLNS', 'node': 'adp_c', 'direction': 'head'},
#   {'edge': 'GLNS', 'node': 'gln__L_c', 'direction': 'head'},
#   {'edge': 'GLNabc', 'node': 'h2o_c', 'direction': 'tail'},
#   {'edge': 'GLNabc', 'node': 'gln__L_e', 'direction': 'tail'},
#   {'edge': 'GLNabc', 'node': 'atp_c', 'direction': 'tail'},
#   {'edge': 'GLNabc', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'GLNabc', 'node': 'pi_c', 'direction': 'head'},
#   {'edge': 'GLNabc', 'node': 'adp_c', 'direction': 'head'},
#   {'edge': 'GLNabc', 'node': 'gln__L_c', 'direction': 'head'},
#   {'edge': 'GLUDy', 'node': 'glu__L_c', 'direction': 'tail'},
#   {'edge': 'GLUDy', 'node': 'h2o_c', 'direction': 'tail'},
#   {'edge': 'GLUDy', 'node': 'nadp_c', 'direction': 'tail'},
#   {'edge': 'GLUDy', 'node': 'nadph_c', 'direction': 'head'},
#   {'edge': 'GLUDy', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'GLUDy', 'node': 'akg_c', 'direction': 'head'},
#   {'edge': 'GLUDy', 'node': 'nh4_c', 'direction': 'head'},
#   {'edge': 'GLUDy_reverse', 'node': 'nadph_c', 'direction': 'tail'},
#   {'edge': 'GLUDy_reverse', 'node': 'h_c', 'direction': 'tail'},
#   {'edge': 'GLUDy_reverse', 'node': 'akg_c', 'direction': 'tail'},
#   {'edge': 'GLUDy_reverse', 'node': 'nh4_c', 'direction': 'tail'},
#   {'edge': 'GLUDy_reverse', 'node': 'glu__L_c', 'direction': 'head'},
#   {'edge': 'GLUDy_reverse', 'node': 'h2o_c', 'direction': 'head'},
#   {'edge': 'GLUDy_reverse', 'node': 'nadp_c', 'direction': 'head'},
#   {'edge': 'GLUN', 'node': 'h2o_c', 'direction': 'tail'},
#   {'edge': 'GLUN', 'node': 'gln__L_c', 'direction': 'tail'},
#   {'edge': 'GLUN', 'node': 'glu__L_c', 'direction': 'head'},
#   {'edge': 'GLUN', 'node': 'nh4_c', 'direction': 'head'},
#   {'edge': 'GLUSy', 'node': 'nadph_c', 'direction': 'tail'},
#   {'edge': 'GLUSy', 'node': 'h_c', 'direction': 'tail'},
#   {'edge': 'GLUSy', 'node': 'akg_c', 'direction': 'tail'},
#   {'edge': 'GLUSy', 'node': 'gln__L_c', 'direction': 'tail'},
#   {'edge': 'GLUSy', 'node': 'glu__L_c', 'direction': 'head'},
#   {'edge': 'GLUSy', 'node': 'nadp_c', 'direction': 'head'},
#   {'edge': 'GLUt2r', 'node': 'glu__L_e', 'direction': 'tail'},
#   {'edge': 'GLUt2r', 'node': 'h_e', 'direction': 'tail'},
#   {'edge': 'GLUt2r', 'node': 'glu__L_c', 'direction': 'head'},
#   {'edge': 'GLUt2r', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'GLUt2r_reverse', 'node': 'glu__L_c', 'direction': 'tail'},
#   {'edge': 'GLUt2r_reverse', 'node': 'h_c', 'direction': 'tail'},
#   {'edge': 'GLUt2r_reverse', 'node': 'glu__L_e', 'direction': 'head'},
#   {'edge': 'GLUt2r_reverse', 'node': 'h_e', 'direction': 'head'},
#   {'edge': 'GND', 'node': '6pgc_c', 'direction': 'tail'},
#   {'edge': 'GND', 'node': 'nadp_c', 'direction': 'tail'},
#   {'edge': 'GND', 'node': 'nadph_c', 'direction': 'head'},
#   {'edge': 'GND', 'node': 'co2_c', 'direction': 'head'},
#   {'edge': 'GND', 'node': 'ru5p__D_c', 'direction': 'head'},
#   {'edge': 'H2Ot', 'node': 'h2o_e', 'direction': 'tail'},
#   {'edge': 'H2Ot', 'node': 'h2o_c', 'direction': 'head'},
#   {'edge': 'H2Ot_reverse', 'node': 'h2o_c', 'direction': 'tail'},
#   {'edge': 'H2Ot_reverse', 'node': 'h2o_e', 'direction': 'head'},
#   {'edge': 'ICDHyr', 'node': 'icit_c', 'direction': 'tail'},
#   {'edge': 'ICDHyr', 'node': 'nadp_c', 'direction': 'tail'},
#   {'edge': 'ICDHyr', 'node': 'nadph_c', 'direction': 'head'},
#   {'edge': 'ICDHyr', 'node': 'akg_c', 'direction': 'head'},
#   {'edge': 'ICDHyr', 'node': 'co2_c', 'direction': 'head'},
#   {'edge': 'ICDHyr_reverse', 'node': 'nadph_c', 'direction': 'tail'},
#   {'edge': 'ICDHyr_reverse', 'node': 'akg_c', 'direction': 'tail'},
#   {'edge': 'ICDHyr_reverse', 'node': 'co2_c', 'direction': 'tail'},
#   {'edge': 'ICDHyr_reverse', 'node': 'icit_c', 'direction': 'head'},
#   {'edge': 'ICDHyr_reverse', 'node': 'nadp_c', 'direction': 'head'},
#   {'edge': 'ICL', 'node': 'icit_c', 'direction': 'tail'},
#   {'edge': 'ICL', 'node': 'succ_c', 'direction': 'head'},
#   {'edge': 'ICL', 'node': 'glx_c', 'direction': 'head'},
#   {'edge': 'LDH_D', 'node': 'nad_c', 'direction': 'tail'},
#   {'edge': 'LDH_D', 'node': 'lac__D_c', 'direction': 'tail'},
#   {'edge': 'LDH_D', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'LDH_D', 'node': 'nadh_c', 'direction': 'head'},
#   {'edge': 'LDH_D', 'node': 'pyr_c', 'direction': 'head'},
#   {'edge': 'LDH_D_reverse', 'node': 'h_c', 'direction': 'tail'},
#   {'edge': 'LDH_D_reverse', 'node': 'nadh_c', 'direction': 'tail'},
#   {'edge': 'LDH_D_reverse', 'node': 'pyr_c', 'direction': 'tail'},
#   {'edge': 'LDH_D_reverse', 'node': 'nad_c', 'direction': 'head'},
#   {'edge': 'LDH_D_reverse', 'node': 'lac__D_c', 'direction': 'head'},
#   {'edge': 'MALS', 'node': 'accoa_c', 'direction': 'tail'},
#   {'edge': 'MALS', 'node': 'h2o_c', 'direction': 'tail'},
#   {'edge': 'MALS', 'node': 'glx_c', 'direction': 'tail'},
#   {'edge': 'MALS', 'node': 'mal__L_c', 'direction': 'head'},
#   {'edge': 'MALS', 'node': 'coa_c', 'direction': 'head'},
#   {'edge': 'MALS', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'MALt2_2', 'node': 'mal__L_e', 'direction': 'tail'},
#   {'edge': 'MALt2_2', 'node': 'h_e', 'direction': 'tail'},
#   {'edge': 'MALt2_2', 'node': 'mal__L_c', 'direction': 'head'},
#   {'edge': 'MALt2_2', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'MDH', 'node': 'mal__L_c', 'direction': 'tail'},
#   {'edge': 'MDH', 'node': 'nad_c', 'direction': 'tail'},
#   {'edge': 'MDH', 'node': 'oaa_c', 'direction': 'head'},
#   {'edge': 'MDH', 'node': 'h_c', 'direction': 'head'},
#   {'edge': 'MDH', 'node': 'nadh_c', 'direction': 'head'},
#   {'edge': 'MDH_reverse', 'node': 'oaa_c', 'direction': 'tail'},
#   {'edge': 'MDH_reverse', 'node': 'h_c', 'direction': 'tail'},
#   {'edge': 'MDH_reverse', 'node': 'nadh_c', 'direction': 'tail'},
#   {'edge': 'MDH_reverse', 'node': 'mal__L_c', 'direction': 'head'},
#   {'edge': 'MDH_reverse', 'node': 'nad_c', 'direction': 'head'},
#   {'edge': 'ME1', 'node': 'mal__L_c', 'direction': 'tail'},
#   {'edge': 'ME1', 'node': 'nad_c', 'direction': 'tail'},
#   {'edge': 'ME1', 'node': 'co2_c', 'direction': 'head'},
#   {'edge': 'ME1', 'node': 'nadh_c', 'direction': 'head'},
#   {'edge': 'ME1', 'node': 'pyr_c', 'direction': 'head'},
#   {'edge': 'ME2', 'node': 'mal__L_c', 'direction': 'tail'},
#   {'edge': 'ME2', 'node': 'nadp_c', 'direction': 'tail'},
#   {'edge': 'ME2', 'node': 'nadph_c', 'direction': 'head'},
#   {'edge': 'ME2', 'node': 'co2_c', 'direction': 'head'},
#   {'edge': 'ME2', 'node': 'pyr_c', 'direction': 'head'},
#   {'edge': 'NADH16', 'node': 'h_c', 'direction': 'tail'},
#   {'edge': 'NADH16', 'node': 'nadh_c', 'direction': 'tail'},
#   {'edge': 'NADH16', 'node': 'q8_c', 'direction': 'tail'},
#   {'edge': 'NADH16', 'node': 'nad_c', 'direction': 'head'},
#   {'edge': 'NADH16', 'node': 'h_e', 'direction': 'head'},
#   {'edge': 'NADH16', 'node': 'q8h2_c', 'direction': 'head'},
#   {'edge': 'NADTRHD', 'node': 'nadph_c', 'direction': 'tail'},
#   {'edge': 'NADTRHD', 'node': 'nad_c', 'direction': 'tail'},
#   {'edge': 'NADTRHD', 'node': 'nadh_c', 'direction': 'head'},
#   {'edge': 'NADTRHD', 'node': 'nadp_c', 'direction': 'head'},
#   {'edge': 'NH4t', 'node': 'nh4_e', 'direction': 'tail'},
#   {'edge': 'NH4t', 'node': 'nh4_c', 'direction': 'head'},
#   {'edge': 'NH4t_reverse', 'node': 'nh4_c', 'direction': 'tail'},
#   {'edge': 'NH4t_reverse', 'node': 'nh4_e', 'direction': 'head'},
#   {'edge': 'O2t', 'node': 'o2_e', 'direction': 'tail'},
#   {'edge': 'O2t', 'node': 'o2_c', 'direction': 'head'},
#   {'edge': 'O2t_reverse', 'node': 'o2_c', 'direction': 'tail'},
#   {'edge': 'O2t_reverse', 'node': 'o2_e', 'direction': 'head'},
#   {'edge': 'PDH', 'node': 'coa_c', 'direction': 'tail'},
#   {'edge': 'PDH', 'node': 'nad_c', 'direction': 'tail'},
#   {'edge': 'PDH', 'node': 'pyr_c', 'direction': 'tail'},
#   {'edge': 'PDH', 'node': 'accoa_c', 'direction': 'head'},
#   {'edge': 'PDH', 'node': 'co2_c', 'direction': 'head'},
#   {'edge': 'PDH', 'node': 'nadh_c', 'direction': 'head'}],
#  'network-type': 'directed',
#  'metadata': {'name': 'e_coli_core',
#   'organism': 'Escherichia coli str. K-12 substr. MG1655'}}
